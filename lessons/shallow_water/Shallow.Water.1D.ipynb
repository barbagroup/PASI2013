# %% [markdown]
# #Shallow Water Equations in 1D with ClawPack and PyClaw

# %% [markdown]
# The shallow water equations are hyperbolic partial differential equations that describe fluid flow when the fluid is "shallow."  They're [derived(pdf)](http://kiwi.atmos.colostate.edu/group/dave/pdf/ShallowWater.pdf) from the Navier-Stokes equations for cases where horizontal length is much greater than vertical length.  The vertical velocity is assumed to be effectively zero and so the horizontal velocity is constant throughout the height of the fluid column.
#
# ##Applications
# Shallow water equations are used extensively for tsunami modeling.
#
# ##Getting started

# %% [markdown]
# First, begin by importing the pyclaw and riemann modules from clawpack.  If you don't have Clawpack installed on your system, you can look [here](http://clawpack.github.io/doc/installing.html) for instructions.

# %%
from clawpack import riemann
from clawpack import pyclaw
import numpy

# %% [markdown]
# Clawpack has a number of built in Riemann solvers which are coded in Fortran for nice fast results.  Pyclaw functions as a bridge to allow us to make use of these Fortran routines from within Python.
#
# We're looking at 1D shallow water equations for this example.
#
# The conservative equations have the form
#
# $$\frac{\partial H}{\partial t} + \frac{\partial (UH)}{\partial x} = 0$$
#
# $$\frac{\partial (UH)}{\partial t} + \frac{\partial (U^2 H + \frac{1}{2} g H^2 )}{\partial x} = 0$$
#
# Here U is the ordinary velocity, H is the height of the water column and g is the gravitational acceleration.
#
# For any problem, we have to choose the appropriate Riemann solver.
# For these equations, the Clawpack solver we want is called `shallow_roe_with_efix_1D`.

# %%
rs = riemann.shallow_roe_with_efix_1D

# %% [markdown]
# Next, we need to tell Pyclaw that we're going to be using this Riemann solver and also apply a 'limiter' to the problem.  Limiters are any one of several routines to help prevent problems from blowing up.  For this problem, we'll use a wave limiter called Vanleer.

# %%
solver = pyclaw.ClawSolver1D(rs)
solver.limiters = pyclaw.limiters.tvd.vanleer

# %% [markdown]
# We also have to tell our solver that we're using a Fortran routine to run this problem.

# %%
solver.kernel_language='Fortran'

# %% [markdown]
# Ok, now it's time to set up our domain.  We have to choose a range to run the problem over, and the number of grid points that we'd like to insert.

# %%
xlower = -5.0
xupper = 5.0
mx = 200
x = pyclaw.Dimension('x',xlower,xupper,mx)
domain = pyclaw.Domain(x)

# %% [markdown]
# Note now that x is a pyclaw geometry object.

# %%
print x
# Out:
# Dimension x:  (num_cells,delta,[lower,upper]) = (200,0.05,[-5.0,5.0])

# %% [markdown]
# Next we have to initialize the Pyclaw "state" object.  The state object keeps track of our domain as the solver progresses.  We need to tell it what our domain looks like (conveniently stashed in our variable `x`) and also how many equations are in our problem.  Since we're working with a 1D shallow water problem, we need two equations.

# %%
domain = pyclaw.Domain(x)
num_eqn = 2
state = pyclaw.State(domain,num_eqn)
state.problem_data['grav'] = 1.0

# %% [markdown]
# Ok, now let's set up our initial conditions.  We'll be looking at a classic shallow water example, the 'dam break.'  We're going to set up a 'step' of water and then see what happens when we let it go.  First, let's grab the positions of our nodes from our state object.

# %%
xc = state.grid.x.centers

# %% [markdown]
# For the sake of simplicity, we'll choose $x=0$ as our point to divide the high and low water sections.  Everything to the left of $x=0$ will have a height of 3, while everything to the right will have a height of 1.  We also need to specify an initial velocity at each node.  Again, for simplicity, we're going to set $u=0$ everywhere.
#
# Now, because we need Pyclaw to understand what we're asking it, we need to make sure we put this information in the right place.  In this setup, we need to put our water height information into the first row of the `state.q` array, and the velocity information into the second row.

# %%
x0 = 0

hl = 3.
hr = 1.
state.q[0,:] = hl * (xc <= x0) + hr * (xc > x0)
state.q[1,:] = xc*0

# %% [markdown]
# Let's do a quick of those initial conditions to make sure they turned out the way we expected.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(11,4))
plt.subplot(121)
plt.plot(xc, state.q[0,:])
plt.title('Water height')
plt.subplot(122)
plt.plot(xc, state.q[1,:])
plt.title('Initial velocity');

# %% [markdown]
# Looking good!  Now just a little more housekeeping and we should be good to go.  We need to specify boundary conditions so the solver knows what to do at the edges of our domain.  For a dam break simulation, outflow boundaries make the most sense.

# %%
solver.bc_lower[0] = pyclaw.BC.extrap
solver.bc_upper[0] = pyclaw.BC.extrap

# %% [markdown]
# Finally, we need to specify a few things.  We need to create our 'controller' and initialize a solution object and a solver object.

# %%
claw = pyclaw.Controller()
claw.keep_copy = True
claw.tfinal = 3.0
claw.solution = pyclaw.Solution(state,domain)
claw.solver = solver
claw.output_format = None 
claw.num_output_times = 50

# %%
status = claw.run();
# Out:
# 2014-07-03 12:17:14,715 INFO CLAW: Solution 0 computed for time t=0.000000
# 2014-07-03 12:17:14,722 INFO CLAW: Solution 1 computed for time t=0.060000
# 2014-07-03 12:17:14,727 INFO CLAW: Solution 2 computed for time t=0.120000
# 2014-07-03 12:17:14,732 INFO CLAW: Solution 3 computed for time t=0.180000
# 2014-07-03 12:17:14,738 INFO CLAW: Solution 4 computed for time t=0.240000
# 2014-07-03 12:17:14,743 INFO CLAW: Solution 5 computed for time t=0.300000
# 2014-07-03 12:17:14,745 INFO CLAW: Solution 6 computed for time t=0.360000
# 2014-07-03 12:17:14,749 INFO CLAW: Solution 7 computed for time t=0.420000
# 2014-07-03 12:17:14,751 INFO CLAW: Solution 8 computed for time t=0.480000
# 2014-07-03 12:17:14,754 INFO CLAW: Solution 9 computed for time t=0.540000
# 2014-07-03 12:17:14,756 INFO CLAW: Solution 10 computed for time t=0.600000
# 2014-07-03 12:17:14,759 INFO CLAW: Solution 11 computed for time t=0.660000
# 2014-07-03 12:17:14,761 INFO CLAW: Solution 12 computed for time t=0.720000
# 2014-07-03 12:17:14,764 INFO CLAW: Solution 13 computed for time t=0.780000
# 2014-07-03 12:17:14,767 INFO CLAW: Solution 14 computed for time t=0.840000
# 2014-07-03 12:17:14,769 INFO CLAW: Solution 15 computed for time t=0.900000
# 2014-07-03 12:17:14,772 INFO CLAW: Solution 16 computed for time t=0.960000
# 2014-07-03 12:17:14,774 INFO CLAW: Solution 17 computed for time t=1.020000
# 2014-07-03 12:17:14,777 INFO CLAW: Solution 18 computed for time t=1.080000
# 2014-07-03 12:17:14,781 INFO CLAW: Solution 19 computed for time t=1.140000
# 2014-07-03 12:17:14,783 INFO CLAW: Solution 20 computed for time t=1.200000
# 2014-07-03 12:17:14,786 INFO CLAW: Solution 21 computed for time t=1.260000
# 2014-07-03 12:17:14,789 INFO CLAW: Solution 22 computed for time t=1.320000
# 2014-07-03 12:17:14,792 INFO CLAW: Solution 23 computed for time t=1.380000
# 2014-07-03 12:17:14,795 INFO CLAW: Solution 24 computed for time t=1.440000
# 2014-07-03 12:17:14,798 INFO CLAW: Solution 25 computed for time t=1.500000
# 2014-07-03 12:17:14,801 INFO CLAW: Solution 26 computed for time t=1.560000
# 2014-07-03 12:17:14,804 INFO CLAW: Solution 27 computed for time t=1.620000
# 2014-07-03 12:17:14,807 INFO CLAW: Solution 28 computed for time t=1.680000
# 2014-07-03 12:17:14,810 INFO CLAW: Solution 29 computed for time t=1.740000
# 2014-07-03 12:17:14,813 INFO CLAW: Solution 30 computed for time t=1.800000
# 2014-07-03 12:17:14,816 INFO CLAW: Solution 31 computed for time t=1.860000
# 2014-07-03 12:17:14,819 INFO CLAW: Solution 32 computed for time t=1.920000
# 2014-07-03 12:17:14,822 INFO CLAW: Solution 33 computed for time t=1.980000
# 2014-07-03 12:17:14,825 INFO CLAW: Solution 34 computed for time t=2.040000
# 2014-07-03 12:17:14,827 INFO CLAW: Solution 35 computed for time t=2.100000
# 2014-07-03 12:17:14,830 INFO CLAW: Solution 36 computed for time t=2.160000
# 2014-07-03 12:17:14,833 INFO CLAW: Solution 37 computed for time t=2.220000
# 2014-07-03 12:17:14,836 INFO CLAW: Solution 38 computed for time t=2.280000
# 2014-07-03 12:17:14,838 INFO CLAW: Solution 39 computed for time t=2.340000
# 2014-07-03 12:17:14,840 INFO CLAW: Solution 40 computed for time t=2.400000
# 2014-07-03 12:17:14,842 INFO CLAW: Solution 41 computed for time t=2.460000
# 2014-07-03 12:17:14,845 INFO CLAW: Solution 42 computed for time t=2.520000
# 2014-07-03 12:17:14,847 INFO CLAW: Solution 43 computed for time t=2.580000
# 2014-07-03 12:17:14,850 INFO CLAW: Solution 44 computed for time t=2.640000
# 2014-07-03 12:17:14,853 INFO CLAW: Solution 45 computed for time t=2.700000
# 2014-07-03 12:17:14,856 INFO CLAW: Solution 46 computed for time t=2.760000
# 2014-07-03 12:17:14,858 INFO CLAW: Solution 47 computed for time t=2.820000
# 2014-07-03 12:17:14,860 INFO CLAW: Solution 48 computed for time t=2.880000
# 2014-07-03 12:17:14,862 INFO CLAW: Solution 49 computed for time t=2.940000
# 2014-07-03 12:17:14,864 INFO CLAW: Solution 50 computed for time t=3.000000

# %% [markdown]
# Ok!  So our solver has, well, solved our problem.  It's split it up into 50 frames, just as we specified, and it's covered 3 seconds of simulation time, again as we've specified.  Now let's take a look at the results!
#
# ##Plotting results
#
# The solution for each frame is stored within the array `claw.frames`, so we can easily use `matplotlib` to take a look at a given frame of our solution.  Just like with our initial setup, the fluid height is stored in the first row of `q` and the velocity is stored in the second row.

# %%
x = domain.grid.x.centers.copy()

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(x, claw.frames[17].q[0,:], 'o-')
plt.title('Frame 17 Fluid Height')

plt.subplot(122)
plt.plot(x, claw.frames[17].q[1,:])
plt.title('Frame 17 Velocity');

# %% [markdown]
# ##Animating results
#
# We're going to make use of the JSAnimation library to animate our solutions into a small movie.  You can read up [here](dummylink) about how the JSAnimation library works.

# %%
from matplotlib import animation
from JSAnimation import IPython_display

# %%
fig = plt.figure(figsize=(11,8))
ax = plt.axes(xlim=(-5, 5), ylim=(0, 5))

frame = claw.frames[0]
pressure = frame.q[0,:]
line, = ax.plot([], [], lw=2)

def fplot(i):
    frame = claw.frames[i]
    line.set_data(x,frame.q[0,:])
    return line,

animation.FuncAnimation(fig, fplot, 50, interval=40)

# %% [markdown]
# Cool!  Once you have the hang of setting up the solvers, it's very easy to reinitialize a problem and change the initial conditions.  Here's the same setup but instead of a dam break, we have a perturbation that could model what happens when a droplet of water hits a puddle.

# %%
solver = pyclaw.ClawSolver1D(rs)
solver.limiters = pyclaw.limiters.tvd.vanleer
solver.kernel_language='Fortran'

state = pyclaw.State(domain,num_eqn)
state.problem_data['grav'] = 1.0

solver.bc_lower[0] = pyclaw.BC.extrap
solver.bc_upper[0] = pyclaw.BC.extrap

x0=0
eps=0.5
state.q[0,:] = 1.0 + eps*numpy.exp(-(xc-x0)**2/0.5)
state.q[1,:] = 0.

claw = pyclaw.Controller()
claw.keep_copy = True
claw.tfinal = 3.0
claw.solution = pyclaw.Solution(state,domain)
claw.solver = solver
claw.output_format = None 
claw.num_output_times = 50

# %%
claw.run()
# Out:
# 2014-07-03 12:17:34,620 INFO CLAW: Solution 0 computed for time t=0.000000
# 2014-07-03 12:17:34,627 INFO CLAW: Solution 1 computed for time t=0.060000
# 2014-07-03 12:17:34,632 INFO CLAW: Solution 2 computed for time t=0.120000
# 2014-07-03 12:17:34,637 INFO CLAW: Solution 3 computed for time t=0.180000
# 2014-07-03 12:17:34,642 INFO CLAW: Solution 4 computed for time t=0.240000
# 2014-07-03 12:17:34,646 INFO CLAW: Solution 5 computed for time t=0.300000
# 2014-07-03 12:17:34,650 INFO CLAW: Solution 6 computed for time t=0.360000
# 2014-07-03 12:17:34,653 INFO CLAW: Solution 7 computed for time t=0.420000
# 2014-07-03 12:17:34,656 INFO CLAW: Solution 8 computed for time t=0.480000
# 2014-07-03 12:17:34,659 INFO CLAW: Solution 9 computed for time t=0.540000
# 2014-07-03 12:17:34,662 INFO CLAW: Solution 10 computed for time t=0.600000
# 2014-07-03 12:17:34,664 INFO CLAW: Solution 11 computed for time t=0.660000
# 2014-07-03 12:17:34,666 INFO CLAW: Solution 12 computed for time t=0.720000
# 2014-07-03 12:17:34,668 INFO CLAW: Solution 13 computed for time t=0.780000
# 2014-07-03 12:17:34,669 INFO CLAW: Solution 14 computed for time t=0.840000
# 2014-07-03 12:17:34,671 INFO CLAW: Solution 15 computed for time t=0.900000
# 2014-07-03 12:17:34,673 INFO CLAW: Solution 16 computed for time t=0.960000
# 2014-07-03 12:17:34,674 INFO CLAW: Solution 17 computed for time t=1.020000
# 2014-07-03 12:17:34,676 INFO CLAW: Solution 18 computed for time t=1.080000
# 2014-07-03 12:17:34,679 INFO CLAW: Solution 19 computed for time t=1.140000
# 2014-07-03 12:17:34,682 INFO CLAW: Solution 20 computed for time t=1.200000
# 2014-07-03 12:17:34,685 INFO CLAW: Solution 21 computed for time t=1.260000
# 2014-07-03 12:17:34,688 INFO CLAW: Solution 22 computed for time t=1.320000
# 2014-07-03 12:17:34,691 INFO CLAW: Solution 23 computed for time t=1.380000
# 2014-07-03 12:17:34,694 INFO CLAW: Solution 24 computed for time t=1.440000
# 2014-07-03 12:17:34,696 INFO CLAW: Solution 25 computed for time t=1.500000
# 2014-07-03 12:17:34,699 INFO CLAW: Solution 26 computed for time t=1.560000
# 2014-07-03 12:17:34,702 INFO CLAW: Solution 27 computed for time t=1.620000
# 2014-07-03 12:17:34,705 INFO CLAW: Solution 28 computed for time t=1.680000
# 2014-07-03 12:17:34,708 INFO CLAW: Solution 29 computed for time t=1.740000
# 2014-07-03 12:17:34,711 INFO CLAW: Solution 30 computed for time t=1.800000
# 2014-07-03 12:17:34,713 INFO CLAW: Solution 31 computed for time t=1.860000
# 2014-07-03 12:17:34,716 INFO CLAW: Solution 32 computed for time t=1.920000
# 2014-07-03 12:17:34,718 INFO CLAW: Solution 33 computed for time t=1.980000
# 2014-07-03 12:17:34,720 INFO CLAW: Solution 34 computed for time t=2.040000
# 2014-07-03 12:17:34,723 INFO CLAW: Solution 35 computed for time t=2.100000
# 2014-07-03 12:17:34,725 INFO CLAW: Solution 36 computed for time t=2.160000
# 2014-07-03 12:17:34,727 INFO CLAW: Solution 37 computed for time t=2.220000
# 2014-07-03 12:17:34,730 INFO CLAW: Solution 38 computed for time t=2.280000
# 2014-07-03 12:17:34,733 INFO CLAW: Solution 39 computed for time t=2.340000
# 2014-07-03 12:17:34,736 INFO CLAW: Solution 40 computed for time t=2.400000
# 2014-07-03 12:17:34,738 INFO CLAW: Solution 41 computed for time t=2.460000
# 2014-07-03 12:17:34,741 INFO CLAW: Solution 42 computed for time t=2.520000
# 2014-07-03 12:17:34,743 INFO CLAW: Solution 43 computed for time t=2.580000
# 2014-07-03 12:17:34,746 INFO CLAW: Solution 44 computed for time t=2.640000
# 2014-07-03 12:17:34,748 INFO CLAW: Solution 45 computed for time t=2.700000
# 2014-07-03 12:17:34,751 INFO CLAW: Solution 46 computed for time t=2.760000
# 2014-07-03 12:17:34,753 INFO CLAW: Solution 47 computed for time t=2.820000
# 2014-07-03 12:17:34,755 INFO CLAW: Solution 48 computed for time t=2.880000
# 2014-07-03 12:17:34,757 INFO CLAW: Solution 49 computed for time t=2.940000
# 2014-07-03 12:17:34,760 INFO CLAW: Solution 50 computed for time t=3.000000
# {'cflmax': 0.9050358709266332,
#  'dtmax': 0.036749998404948234,
#  'dtmin': 0.033699477297272531,
#  'numsteps': 100}

# %%
fig = plt.figure(figsize=(11,8))
ax = plt.axes(xlim=(-5, 5), ylim=(0, 2))

frame = claw.frames[0]
pressure = frame.q[0,:]
line, = ax.plot([], [], lw=2)

def fplot(i):
    frame = claw.frames[i]
    line.set_data(x,frame.q[0,:])
    return line,

animation.FuncAnimation(fig, fplot, 50, interval=40)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgEUYNTMQISZQJVYUM">
#     <br>
#     <input id="_anim_sliderEUYNTMQISZQJVYUM" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animEUYNTMQISZQJVYUM.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animEUYNTMQISZQJVYUM.slower()">&#8211;</button>
#     <button onclick="animEUYNTMQISZQJVYUM.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEUYNTMQISZQJVYUM.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectEUYNTMQISZQJVYUM" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgEUYNTMQISZQJVYUM";
#     var slider_id = "_anim_sliderEUYNTMQISZQJVYUM";
#     var loop_select_id = "_anim_loop_selectEUYNTMQISZQJVYUM";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzt3Xuc1nWd9/H3gIriAVTwAEwJIkrraV3TYqlQK0vUgLXs\
# Lha1buw2TfOQWmsbtFlqblbCUuG2S9xm1qamaeEJ0ApLWzFdUSRPI9B6ijyCCHP/8buRWNB0+M78\
# rpl5Ph+P6zG/mbkaPjyuSX6v6/s7NLW2trYGAACggB51DwAAAHQdAgMAAChGYAAAAMUIDAAAoBiB\
# AQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQG\
# AABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgA\
# AEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAA\
# AMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAA\
# FCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBUUBLS0ve/e53p7m5OUOH\
# Ds3UqVPXe87KlSszYcKEDB48OPvtt1/uu+++GiYFAID2JTAKaGpqyqRJk9LS0pJ58+blvPPOy4IF\
# C9Z5zsyZM7NixYo89NBDmTx5ck455ZSapgUAgPYjMAoYNGhQRo4cmSTp379/dt999yxdunSd51x9\
# 9dU55phjkiSHH3545s+fn+eff77DZwUAgPYkMApbuHBhFi5cmAMPPHCdry9evDiDBg1KUq14DBgw\
# IEuWLKljRAAAaDcCo6Bly5bl6KOPzvTp07Plllu+5nNXr17dQVMBAEDH2aTuAbqK5cuXZ8yYMTnl\
# lFNy6KGHrvf9gQMHpqWlJXvvvXdaW1uzdOnSDBgwYJ3n7Lvvvrnrrrs6amQAAF7FPvvsk/nz59c9\
# RqdkBaOAVatW5UMf+lDe97735dhjj33l63fffXcWLlyYJDnyyCMzY8aMJNX5GPvuu+96qxx33XVX\
# Wltbu9XjC1/4Qu0zeHitPbzWHl5rD6/z/3x407ftrGAUMHfu3Pz0pz/NnXfe+colai+++OL88pe/\
# TL9+/XLWWWdlwoQJmT17dpqbm9OvX79cdtllNU8NAADlCYwCDj744A2eUzFmzJhXtjfZZJPMnDmz\
# I8cCAIAO5xApajVq1Ki6R6CDeK27D6919+G17h68zrxRTa2tra11D0GlqakpXg4AgPrZL2s7KxgA\
# AEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAA\
# AMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAA\
# FCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQ\
# jMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAx\
# AgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUI\
# DAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMw\
# AACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAA\
# AACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMA\
# AChGYAAAAMUIDAAAoBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAA\
# oBiBAQAAFCMwAACAYgQGAABQjMAAAACKERgAAEAxAgMAAChGYAAAAMUIDAAAoBiBUcD48eOzww47\
# ZK+99trg96dMmZI+ffqkubk5zc3NmT59egdPCAAAHUNgFHD88cfnuuuue9XvNzU15ayzzkpLS0ta\
# WloyceLEDpwOAAA6jsAo4J3vfGf69u37ms9pbW3toGkAAKA+AqODXHzxxRk8eHDGjRuXxx57rO5x\
# AACgXTS1emu9iEWLFmXs2LG5++671/ve448/nj59+mTTTTfNBRdckJtuuik33HDDes9ramqy0gF0\
# Ok8+mfzwh8mttyarV1df23zz5P3vTz7wgWSLLeqdD6At7Je13SZ1D9Ad7LDDDq9sn3TSSTn//PNf\
# 9bmTJk16ZXvUqFEZNWpUO04G0Hbz5iXnnZdcd13y8svrf/9730u23jo56qjk859PBg/u+BkBXq85\
# c+Zkzpw5dY/RJVjBKOR/rmDcfffd6dWrV4YNG5YHHnggQ4cOTVNTU6ZMmZIf/ehHmTt37no/QykD\
# ncHLLyf/9E/Jl7

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
# 	h4{
# 		font-family: 'Fenix', serif;
#        }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render{
#         font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro";
# 			font-size: 90%;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
# 		line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
